# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Credit score cards are used in the financial industry to predict the likelihood of credit card defaults and guide the issuance of credit cards. These scores rely on applicants' personal data and historical information, quantifying risk objectively.

# %% [markdown]
# ### Loading Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading Dataset (application_record)

# %%
data = pd.read_csv(r"C:\Users\ss\Downloads\application_record.csv")

# %% [markdown]
# ### Understanding the dataset

# %%
data
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [438557 rows x 18 columns]

# %%
data.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0        Civil marriage   Rented apartment      -12005          -4542
# 1        Civil marriage   Rented apartment      -12005          -4542
# 2               Married  House / apartment      -21474          -1134
# 3  Single / not married  House / apartment      -19110          -3051
# 4  Single / not married  House / apartment      -19110          -3051
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                1           0           0             NaN
# 1           1                1           0           0             NaN
# 2           1                0           0           0  Security staff
# 3           1                0           1           1     Sales staff
# 4           1                0           1           1     Sales staff
#
#    CNT_FAM_MEMBERS
# 0              2.0
# 1              2.0
# 2              2.0
# 3              1.0
# 4              1.0

# %%
data.tail()
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
#  15  FLAG_EMAIL           438557 non-null  int64
#  16  OCCUPATION_TYPE      304354 non-null  object
#  17  CNT_FAM_MEMBERS      438557 non-null  float64
# dtypes: float64(2), int64(8), object(8)
# memory usage: 60.2+ MB

# %%
dim = data.shape
print("The number of rows:", dim[0])
print("The number of columns:", dim[1])
# Out:
# The number of rows: 438557
# The number of columns: 18

# %% [markdown]
# ### Observation
# * The dataset of application record contains 438557 rows and 18 columns.
# * The dataset consists of 8 columns of object datatype.
# * The remaining 10 columns are of numeric datatype.pe

# %% [markdown]
# ### Loading Dataset (credit_record)

# %%
data2 = pd.read_csv(r"C:\Users\ss\Downloads\credit_record.csv")

# %%
data2
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
data2.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %%
data2.tail()
# Out:
#               ID  MONTHS_BALANCE STATUS
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C

# %%
dim2 = data2.shape
print("The number of rows:", dim2[0])
print("the number of columns:", dim2[1])
# Out:
# The number of rows: 1048575
# the number of columns: 3

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   ID              1048575 non-null  int64
#  1   MONTHS_BALANCE  1048575 non-null  int64
#  2   STATUS          1048575 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 24.0+ MB

# %% [markdown]
# ### Observation
# * The dataset of Credit Record consists of 1048575 rows and 3 columns.
# * The dataset consists of 1 column of object datatype.
# * The remaining 2 columns are of numeric datatype.

# %% [markdown]
# ### Merging two DataFrames

# %%
df = pd.merge(data, data2, on='ID', how='inner')
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage  Rented apartment      -12005          -4542
# 1             Civil marriage  Rented apartment      -12005          -4542
# 2             Civil marriage  Rented apartment      -12005          -4542
# 3             Civil marriage  Rented apartment      -12005          -4542
# 4             Civil marriage  Rented apartment      -12005          -4542
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment       -9188          -1193
# 777711  Single / not married  Rented apartment       -9188          -1193
# 777712  Single / not married  Rented apartment       -9188          -1193
# 777713  Single / not married  Rented apartment       -9188          -1193
# 777714  Single / not married  Rented apartment       -9188          -1193
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                1           0           0             NaN
# 3                1                1           0           0             NaN
# 4                1                1           0           0             NaN
# ...            ...              ...         ...         ...             ...
# 777710           1                0           0           0        Laborers
# 777711           1                0           0           0        Laborers
# 777712           1                0           0           0        Laborers
# 777713           1                0           0           0        Laborers
# 777714           1                0           0           0        Laborers
#
#         CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                   2.0               0      C
# 1                   2.0              -1      C
# 2                   2.0              -2      C
# 3                   2.0              -3      C
# 4                   2.0              -4      C
# ...                 ...             ...    ...
# 777710              1.0              -9      0
# 777711              1.0             -10      2
# 777712              1.0             -11      1
# 777713              1.0             -12      0
# 777714              1.0             -13      0
#
# [777715 rows x 20 columns]

# %% [markdown]
# * We merge two dataframes on basis of ID column present in both datasets.
# * Moreover, Credit record dataset has more records of clients than Application record dataset, so we make sure that our new datafrmae df contains only those rows which have the same ID number.
# * For that purose we use inner parameter in pd.merge function.

# %% [markdown]
# ### Previewing the Merged Data

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008804           M            Y               Y             0
# 2  5008804           M            Y               Y             0
# 3  5008804           M            Y               Y             0
# 4  5008804           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
# 2          427500.0          Working    Higher education     Civil marriage
# 3          427500.0          Working    Higher education     Civil marriage
# 4          427500.0          Working    Higher education     Civil marriage
#
#   NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 0  Rented apartment      -12005          -4542           1                1
# 1  Rented apartment      -12005          -4542           1                1
# 2  Rented apartment      -12005          -4542           1                1
# 3  Rented apartment      -12005          -4542           1                1
# 4  Rented apartment      -12005          -4542           1                1
#
#    FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE  \
# 0           0           0             NaN              2.0               0
# 1           0           0             NaN              2.0              -1
# 2           0           0             NaN              2.0              -2
# 3           0           0             NaN              2.0              -3
# 4           0           0             NaN              2.0              -4
#
#   STATUS
# 0      C
# 1      C
# 2      C
# 3      C
# 4      C

# %%
df.tail()
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 777710  Single / not married  Rented apartment       -9188          -1193
# 777711  Single / not married  Rented apartment       -9188          -1193
# 777712  Single / not married  Rented apartment       -9188          -1193
# 777713  Single / not married  Rented apartment       -9188          -1193
# 777714  Single / not married  Rented apartment       -9188          -1193
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 777710           1                0           0           0        Laborers
# 777711           1                0           0           0        Laborers
# 777712           1                0           0           0        Laborers
# 777713           1                0           0           0        Laborers
# 777714           1                0           0           0        Laborers
#
#         CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 777710              1.0              -9      0
# 777711              1.0             -10      2
# 777712              1.0             -11      1
# 777713              1.0             -12      0
# 777714              1.0             -13      0

# %%
print("Number of rows of merged data:", df.shape[0])
print("Number of columns of merged data:", df.shape[1])
# Out:
# Number of rows of merged data: 777715
# Number of columns of merged data: 20

# %% [markdown]
# ### Observation:
# * At earlier we have seen that Application record dataset has 438557 rows
# * Now, our merged dataset has only contain 777715
# * That means Application Record & Credit Record dataset has only 777715 rows which have common ID numbers

# %% [markdown]
# ### Checking for missing value and dealing with them

# %%
df.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        240048
# CNT_FAM_MEMBERS             0
# MONTHS_BALANCE              0
# STATUS                      0
# dtype: int64

# %% [markdown]
# This shows that only one columns consists of null values, i.e., OCCUPATION_TYPE

# %%
data.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# 25%     -3103.000000         1.0         0.000000       0.000000
# 50%     -1467.000000         1.0         0.000000       0.000000
# 75%      -371.000000         1.0         0.000000       1.000000
# max    365243.000000         1.0         1.000000       1.000000
#
#           FLAG_EMAIL  CNT_FAM_MEMBERS
# count  438557.000000    438557.000000
# mean        0.108207         2.194465
# std         0.310642         0.897207
# min         0.000000         1.000000
# 25%         0.000000         2.000000
# 50%         0.000000         2.000000
# 75%         0.000000         3.000000
# max         1.000000        20.000000

# %%
# plotting heatmap for checking null values
plt.figure(figsize=(10,6))

# plotting the heatmap for missing values
sns.heatmap(df.isna(), yticklabels=False, cbar=False, cmap='viridis')

plt.title("Heatmap for missing values")
plt.show()

# %%
# Check the percentage of missing value 
df['OCCUPATION_TYPE'].isna().sum()/df.shape[0] * 100
# Out:
# 30.86580559716606

# %% [markdown]
# ### Observation:
# * There are only one column in our datafrme which has null values.
# * This column is OCCUPATION_TYPE and it has 240048 missing values and it has percentage of 30.86% missing values.
#
# * We have only one option which is to drop the column OCCUPATION_TYPE because it has a high percentage of missing values and secondly every person has itd own unique record. and we cannot simply impute the missing values with mode.

# %%
# dropping the OCCUPATION_TYPE column

df.drop('OCCUPATION_TYPE', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'CNT_FAM_MEMBERS', 'MONTHS_BALANCE', 'STATUS'],
#       dtype='object')

# %% [markdown]
# ### Checking for unique value count in DataFrame

# %%
df.nunique()
# Out:
# ID                     36457
# CODE_GENDER                2
# FLAG_OWN_CAR               2
# FLAG_OWN_REALTY            2
# CNT_CHILDREN               9
# AMT_INCOME_TOTAL         265
# NAME_INCOME_TYPE           5
# NAME_EDUCATION_TYPE        5
# NAME_FAMILY_STATUS         5
# NAME_HOUSING_TYPE          6
# DAYS_BIRTH              7183
# DAYS_EMPLOYED           3640
# FLAG_MOBIL                 1
# FLAG_WORK_PHONE            2
# FLAG_PHONE                 2
# FLAG_EMAIL                 2
# CNT_FAM_MEMBERS           10
# MONTHS_BALANCE            61
# STATUS                     8
# dtype: int64

# %% [markdown]
# ### Observation:
# * Our dataset has 777715 rows but there are only 36457 unique values in ID column.
# * This shows that there maybe duplicates in our dataset.

# %% [markdown]
# ### Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df['ID'].duplicated()].head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 1  5008804           M            Y               Y             0
# 2  5008804           M            Y               Y             0
# 3  5008804           M            Y               Y             0
# 4  5008804           M            Y               Y             0
# 5  5008804           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 1          427500.0          Working    Higher education     Civil marriage
# 2          427500.0          Working    Higher education     Civil marriage
# 3          427500.0          Working    Higher education     Civil marriage
# 4          427500.0          Working    Higher education     Civil marriage
# 5          427500.0          Working    Higher education     Civil marriage
#
#   NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 1  Rented apartment      -12005          -4542           1                1
# 2  Rented apartment      -12005          -4542           1                1
# 3  Rented apartment      -12005          -4542           1                1
# 4  Rented apartment      -12005          -4542           1                1
# 5  Rented apartment      -12005          -4542           1                1
#
#    FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 1           0           0              2.0              -1      C
# 2           0           0              2.0              -2      C
# 3           0           0              2.0              -3      C
# 4           0           0              2.0              -4      C
# 5           0           0              2.0              -5      C

# %%
df[df['ID'].duplicated()].tail()
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 777710  Single / not married  Rented apartment       -9188          -1193
# 777711  Single / not married  Rented apartment       -9188          -1193
# 777712  Single / not married  Rented apartment       -9188          -1193
# 777713  Single / not married  Rented apartment       -9188          -1193
# 777714  Single / not married  Rented apartment       -9188          -1193
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  \
# 777710           1                0           0           0              1.0
# 777711           1                0           0           0              1.0
# 777712           1                0           0           0              1.0
# 777713           1                0           0           0              1.0
# 777714           1                0           0           0              1.0
#
#         MONTHS_BALANCE STATUS
# 777710              -9      0
# 777711             -10      2
# 777712             -11      1
# 777713             -12      0
# 777714             -13      0

# %% [markdown]
# ### Observation:
# * By carefully checking the dataset we can say that on basis of number of unique enteries in ID column we have data of 36457 clients.
# * And there are no duplicates in our dataset the data of 36457 ID which is collected on the basis of different months of MONTHS_BALANCE

# %% [markdown]
# ### Renaming the columns

# %%
df.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'CNT_FAM_MEMBERS', 'MONTHS_BALANCE', 'STATUS'],
#       dtype='object')

# %%
# Renaming the column in a meaningful way

df.rename(columns={'CODE_GENDER': 'gender',
    'FLAG_OWN_CAR': 'own_car',
    'FLAG_OWN_REALTY': 'own_property',
    'CNT_CHILDREN': 'children',
    'AMT_INCOME_TOTAL': 'income',
    'NAME_INCOME_TYPE': 'income_type',
    'NAME_EDUCATION_TYPE': 'education',
    'NAME_FAMILY_STATUS': 'family_status',
    'NAME_HOUSING_TYPE': 'housing_type',
    'FLAG_MOBIL': 'mobile',
    'FLAG_WORK_PHONE': 'work_phone',
    'FLAG_PHONE': 'phone',
    'FLAG_EMAIL': 'email',
    'CNT_FAM_MEMBERS': 'family_members',
    'MONTHS_BALANCE': 'months_balance',
    'STATUS' : 'status',
    'DAYS_BIRTH' : 'age_in_days',
    'DAYS_EMPLOYED' : 'employment_in_days'}, inplace= True)

# %%
df.columns
# Out:
# Index(['ID', 'gender', 'own_car', 'own_property', 'children', 'income',
#        'income_type', 'education', 'family_status', 'housing_type',
#        'age_in_days', 'employment_in_days', 'mobile', 'work_phone', 'phone',
#        'email', 'family_members', 'months_balance', 'status'],
#       dtype='object')

# %% [markdown]
# ### Mapping the values in a meaningful way

# %%
# Checking for columns with object data type.
df.select_dtypes(include=['object']).columns
# Out:
# Index(['gender', 'own_car', 'own_property', 'income_type', 'education',
#        'family_status', 'housing_type', 'status'],
#       dtype='object')

# %%
# checking for unique values in some columns

col= ['gender', 'own_car', 'own_property']

for i in col:
    print(f'{df[i].value_counts()}')
# Out:
# gender
# F    518851
# M    258864
# Name: count, dtype: int64
# own_car
# N    473355
# Y    304360
# Name: count, dtype: int64
# own_property
# Y    512948
# N    264767
# Name: count, dtype: int64

# %%
# mapping the values in some columns
df['gender']= df['gender'].map({'F':'Female', 'M':'Male'})

df['own_car'] = df['own_car'].map({'Y':'Yes', 'N':'No'})

df['own_property'] = df['own_property'].map({'Y':'Yes', 'N':'No'})

# %%
# check for unique value in status column

df['status'].value_counts()
# Out:
# status
# C    329536
# 0    290654
# X    145950
# 1      8747
# 5      1527
# 2       801
# 3       286
# 4       214
# Name: count, dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
# mapping the values in the status column and sorting results in a new column

df['loan_status'] = df['status'].map({'0':'1st_month_due', '1':'2nd_month_due', '2':'3rd_month_due', '3':'4th_month_due', '4':'5th_month_due', '5':'bad_debt', 'C':'good', 'X':'no_loan'})

# %%
df.columns
# Out:
# Index(['ID', 'gender', 'own_car', 'own_property', 'children', 'income',
#        'income_type', 'education', 'family_status', 'housing_type',
#        'age_in_days', 'employment_in_days', 'mobile', 'work_phone', 'phone',
#        'email', 'family_members', 'months_balance', 'status', 'loan_status'],
#       dtype='object')

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Purpose:
# * The main goal of the analysis is to get ideas about the different attributes of the clients.
# * To get an overview of the distribution of the data.
# * To get an overview of the relationship between the attributes.
# * Particularly, to get an overview of the relationship between the attributes and the target variable[loan_status].

# %% [markdown]
# #### Checking for Distribution

# %%
sns.catplot(data=df, kind='box', height=5, aspect=3)

# %%
columns=['gender', 'own_car', 'own_property']

plt.figure(figsize= (16, 9))

for i in range(len(columns)):
    plt.subplot(1, 3, i+1)
    plt.title(columns[i])

    counts = df[columns[i]].value_counts()
    plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
    plt.legend(counts.index)
plt.show()

# %%
df['gender'].value_counts().index
# Out:
# Index(['Female', 'Male'], dtype='object', name='gender')

# %%
col = ['gender', 'own_car', 'own_property', 'income_type']

plt.figure(figsize=(15, 9))
for i in range(len(col)):
    plt.subplot(2, 2, i+1)
    plt.title(col[i])

    sns.countplot(data=df, x=df[col[i]])
    plt.xticks(rotation=40)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation:
# * There are more Female clients in our dataframe than the male clients.
# * The number of clients who don't have car is more than the number of clients who have car.
# * More number of clients have their own property.

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# good             329536
# 1st_month_due    290654
# no_loan          145950
# 2nd_month_due      8747
# bad_debt           1527
# 3rd_month_due       801
# 4th_month_due       286
# 5th_month_due       214
# Name: count, dtype: int64

# %% [markdown]
# ### Observation:
# * Most of the clients in our dataset have paid off their loan for that month.
# * First-month loan due and no loan for the month comes at 2nd and 3rd place respectively in terms of value counts.
# * 1527 clients have bad debt.

# %%
# plotting count plot of loan status vs gender

plt.figure(figsize=(15, 5))
sns.countplot(data=df, x='loan_status', hue='gender')
plt.title("loan status v/s gender")
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# ### Getting the value count of loan status v/s gender which are less than 10000

# %%
filtered_loan = df.groupby(by=['loan_status'])['gender'].value_counts()

filtered_loan[filtered_loan < 10000].unstack()
# Out:
# gender         Female  Male
# loan_status
# 2nd_month_due    5530  3217
# 3rd_month_due     510   291
# 4th_month_due     178   108
# 5th_month_due     128    86
# bad_debt          809   718

# %% [markdown]
# ### Bar Plot of the relationship between loan_status and gender which have values less than 10000

# %%
plt.figure(figsize=(15, 9))

filtered_loan[filtered_loan < 10000].unstack().plot(kind='barh')
# Out:
# <Axes: ylabel='loan_status'>

# %% [markdown]
# ### Observation:
# * As our dataset has more number of females than males so the count of female is larger than the count of males who have paid off their loan for that month and have no loan for the month
# * Moreover, the females have more over due and bad debt than males.

# %%
df.columns
# Out:
# Index(['ID', 'gender', 'own_car', 'own_property', 'children', 'income',
#        'income_type', 'education', 'family_status', 'housing_type',
#        'age_in_days', 'employment_in_days', 'mobile', 'work_phone', 'phone',
#        'email', 'family_members', 'months_balance', 'status', 'loan_status'],
#       dtype='object')

# %%
# checking value count of income type
df['income_type'].value_counts()
# Out:
# income_type
# Working                 400164
# Commercial associate    183385
# Pensioner               128392
# State servant            65437
# Student                    337
# Name: count, dtype: int64

# %% [markdown]
# #### Checking the relationship between income type and gender

# %%
plt.figure(figsize=(15, 8))
sns.countplot(data=df, x='income_type', hue='gender')
# Out:
# <Axes: xlabel='income_type', ylabel='count'>

# %%
inc= df['income_type'].value_counts()

plt.figure(figsize=(16,9))

for i in range(len(inc)):
    plt.subplot(2, 3, i+1)
    plt.title(inc.index[i])
    sns.countplot(data=df[df['income_type'] == inc.index[i]], x='gender')

# %% [markdown]
# ### Observation:
# * In Working and Commercial assciate income_type the number of male clients is half of the female clients.
# * Whereas, in income_type = Pensioner and  Students males ATM clients numbers are very less as compared to females.

# %% [markdown]
# #### Checking the relationship between loan status and income type

# %%
plt.figure(figsize=(20,9))
sns.countplot(x='loan_status', hue='income_type', data=df)
plt.title("Countplot of loan status vs income type")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation:
# * Most of the clients with working income_type have paid off their loan for that month
# * Similar trend can be seen in the income catagories like first_month_due & no_loan_for_month working catagory comes top of the list followed by commercial associates & pensioners

# %% [markdown]
# #### getting insights from gender vs income type & loan status with value count less than 1000

# %%
count = df.groupby('gender')[['loan_status', 'income_type']].value_counts()
count[count<1000].unstack(level=1)
# Out:
# loan_status                  1st_month_due  2nd_month_due  3rd_month_due  \
# gender income_type
# Female Commercial associate            NaN            NaN          117.0
#        Pensioner                       NaN          950.0          143.0
#        State servant                   NaN          592.0           26.0
#        Student                        57.0            NaN            NaN
#        Working                         NaN            NaN          224.0
# Male   Commercial associate            NaN          883.0           70.0
#        Pensioner                       NaN          207.0           30.0
#        State servant                   NaN          175.0           13.0
#        Student                        10.0            1.0            NaN
#        Working                         NaN            NaN          178.0
#
# loan_status                  4th_month_due  5th_month_due  bad_debt   good  \
# gender income_type
# Female Commercial associate           47.0           45.0     284.0    NaN
#        Pensioner                      66.0           35.0     252.0    NaN
#        State servant                  12.0            6.0      47.0    NaN
#        Student                         NaN            NaN       NaN  196.0
#        Working                        53.0           42.0     226.0    NaN
# Male   Commercial associate           30.0           27.0     277.0    NaN
#        Pensioner                      14.0            9.0      61.0    NaN
#        State servant                   5.0            2.0      14.0    NaN
#        Student                         NaN            NaN       NaN    4.0
#        Working                        59.0           48.0     366.0    NaN
#
# loan_status                  no_loan
# gender income_type
# Female Commercial associate      NaN
#        Pensioner                 NaN
#        State servant             NaN
#        Student                  69.0
#        Working                   NaN
# Male   Commercial associate      NaN
#        Pensioner                 NaN
#        State servant             NaN
#        Student                   NaN
#        Working                   NaN

# %%
count = df.groupby('gender')[['loan_status', 'income_type']].value_counts()
count[count<1000].unstack().plot(kind='bar', figsize=(10,5), legend=True)

plt.title('Relationship between gender v/s loan status and income type [value count < 1000]')
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# #### Area Plot of the relationship between gender v/s income type & loan status with value counts less than 1000

# %%
count = df.groupby('gender')[['loan_status', 'income_type']].value_counts()
count[count<1000].unstack().plot(kind='area', figsize=(15,6), legend=True)
plt.title('Relationship between gender v/s loan status and income type [value count < 1000]')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Observation:
# * When we see loan_status trends in terms of income_type and gender we can see that the male with student inocme_type has no_loan for that month.
# * Also, In good & first month due loan_status the number male students is very low and compared to females.
# * State servants income type in both male and female gender have very less numbers in billing overdue of loan_status
# * Both males and females students has 1 and 0 numbers respectively in 2nd_month_due of loan_status.

# %% [markdown]
# #### Getting insights from education and gender

# %%
df['education'].value_counts()
# Out:
# education
# Secondary / secondary special    524261
# Higher education                 213633
# Incomplete higher                 30329
# Lower secondary                    8655
# Academic degree                     837
# Name: count, dtype: int64

# %% [markdown]
# #### Value count of education v/s gender

# %%
df.groupby('gender')[['education']].value_counts()
# Out:
# gender  education
# Female  Secondary / secondary special    349975
#         Higher education                 144457
#         Incomplete higher                 18638
#         Lower secondary                    5177
#         Academic degree                     604
# Male    Secondary / secondary special    174286
#         Higher education                  69176
#         Incomplete higher                 11691
#         Lower secondary                    3478
#         Academic degree                     233
# Name: count, dtype: int64

# %% [markdown]
# #### plotting the value count of education v/s gender

# %%
df.groupby('gender')['education'].value_counts().unstack().plot(kind='bar', figsize=(8,4), stacked=True)
plt.title('Relationship between gender and education')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Observation:
# * As our dataset has larget number of people with secondary education.
# * Therefore, the number of male and female with secondary education is high.
# * Moreover, the number of Lower_secondary & Academic degree is very less in both male and female
# * The proportion of Lower_secondary eduaction is similar for both genders

# %% [markdown]
# ##### Getting insights from education and loan status

# %%
df.groupby('education')[['loan_status']].value_counts().unstack()
# Out:
# loan_status                    1st_month_due  2nd_month_due  3rd_month_due  \
# education
# Academic degree                        208.0            8.0            NaN
# Higher education                     77192.0         2264.0          225.0
# Incomplete higher                    11241.0          535.0           47.0
# Lower secondary                       2708.0          112.0           14.0
# Secondary / secondary special       199305.0         5828.0          515.0
#
# loan_status                    4th_month_due  5th_month_due  bad_debt  \
# education
# Academic degree                          NaN            NaN       NaN
# Higher education                        80.0           55.0     577.0
# Incomplete higher                       18.0           24.0      39.0
# Lower secondary                          5.0            8.0      40.0
# Secondary / secondary special          183.0          127.0     871.0
#
# loan_status                        good  no_loan
# education
# Academic degree                   474.0    147.0
# Higher education                90177.0  43063.0
# Incomplete higher               13282.0   5143.0
# Lower secondary                  4237.0   1531.0
# Secondary / secondary special  221366.0  96066.0

# %%
df.groupby('education')[['loan_status']].value_counts().unstack().plot(kind='bar', figsize=(15, 5), legend=True, stacked=True)
plt.xticks(rotation=60)
plt.title("Relationship between loan_status and gender")
plt.show()

# %% [markdown]
# #### plot the barh for education v/s loan status [values < 500]

# %%
count = df.groupby('education')[['loan_status']].value_counts()
count[count < 500].unstack().plot(kind='barh', figsize=(9,6), legend=True)

plt.title("Relationship between education and loan status  [values < 500]")
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# ### Observation:
# * As our dataset has larget number of people with secondary education and they have largest numbers who have paid off their loan.
# * A similar trend can be seen in the Academic degree education.
# * The mostly people who have bad debt are from Lower_secondary & Incomplete higher education.

# %% [markdown]
# #### Getting insights from housing type and loan status

# %%
# checking for value counts for housing_type column
df['housing_type'].value_counts()
# Out:
# housing_type
# House / apartment      697151
# With parents            35735
# Municipal apartment     24640
# Rented apartment        10898
# Office apartment         5636
# Co-op apartment          3655
# Name: count, dtype: int64

# %%
# checking for unique entries for housing_type column
df['housing_type'].unique()
# Out:
# array(['Rented apartment', 'House / apartment', 'Municipal apartment',
#        'With parents', 'Co-op apartment', 'Office apartment'],
#       dtype=object)

# %%
# Checking for the relationship between housing_type and loan_status
plt.figure(figsize=(15,5))
count = df.groupby('housing_type')[['loan_status']].value_counts()
count.unstack().plot(kind='bar')

plt.title("Relationship between housing type and loan status")
plt.xticks(rotation=25)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='housing_type', hue='loan_status', data=df)
plt.xticks(rotation=25)
plt.title("Relationship between housing type and loan status")
plt.show()

# %% [markdown]
# #### filtering the value counts housing & loan_status==bad_debt

# %%
count = df.groupby(['housing_type', 'loan_status']).size()
bad_loan = count[count.index.get_level_values('loan_status')=='bad_debt']
bad_loan
# Out:
# housing_type         loan_status
# Co-op apartment      bad_debt         16
# House / apartment    bad_debt       1368
# Municipal apartment  bad_debt         54
# Office apartment     bad_debt         14
# Rented apartment     bad_debt         29
# With parents         bad_debt         46
# dtype: int64

# %%
# plotting the value count < 1000 for housing type and loan status
count = df.groupby(['housing_type', 'loan_status']).size()
count[count < 1000].unstack().plot(kind='barh', figsize=(15,5), legend=True)

plt.title("Relationship between loan_status and housing_status [value count < 1000]")
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# #### Observation:
# * Mostly people who have their own house have good , first month due & no_loan loan_status which is a positive trend.
# * People who live with parents have largest share in 2nd_month_due loan_status. This trend is followed by Municipal apartment, Rented apartment and With office apartment respectively.
# * The people with lowest number of bad_debt loan_status are from office apartment & co apartment housing type.

# %% [markdown]
# #### Getting insights from family members and loan status

# %%
df['family_members'].value_counts()
# Out:
# family_members
# 2.0     423723
# 1.0     141477
# 3.0     134894
# 4.0      66990
# 5.0       8999
# 6.0       1196
# 7.0        273
# 15.0       111
# 9.0         46
# 20.0         6
# Name: count, dtype: int64

# %%
# Checking the relationship between family_members and loan_status

df.groupby('family_members')[['loan_status']].value_counts().unstack()
# Out:
# loan_status     1st_month_due  2nd_month_due  3rd_month_due  4th_month_due  \
# family_members
# 1.0                   53411.0         1651.0          179.0           71.0
# 2.0                  157392.0         4571.0          414.0          161.0
# 3.0                   50885.0         1528.0          132.0           34.0
# 4.0                   25110.0          858.0           54.0           15.0
# 5.0                    3234.0          108.0           21.0            4.0
# 6.0                     463.0           16.0            1.0            1.0
# 7.0                      57.0            NaN            NaN            NaN
# 9.0                      14.0           10.0            NaN            NaN
# 15.0                     82.0            5.0            NaN            NaN
# 20.0                      6.0            NaN            NaN            NaN
#
# loan_status     5th_month_due  bad_debt      good  no_loan
# family_members
# 1.0                      52.0     239.0   59894.0  25980.0
# 2.0                     108.0     808.0  181131.0  79138.0
# 3.0                      34.0     381.0   54889.0  27011.0
# 4.0                      18.0      92.0   29037.0  11806.0
# 5.0                       1.0       5.0    4068.0   1558.0
# 6.0                       1.0       2.0     442.0    270.0
# 7.0                       NaN       NaN      53.0    163.0
# 9.0                       NaN       NaN      22.0      NaN
# 15.0                      NaN       NaN       NaN     24.0
# 20.0                      NaN       NaN       NaN      NaN

# %% [markdown]
# ### Observation:
# * Most of the clients have 2 family members.
# * The loan_status of the atm users is good , first month due & no_loan who have 1 ,2 or 3 family members which is a positive trend.
# * Whereas, the number for loan status = 2nd month due is comparatively high for 2 family members

# %% [markdown]
# #### Checking the relationship between children count and loan status

# %%
# Checking the column names with the numeric data types

df.select_dtypes(exclude='object').columns
# Out:
# Index(['ID', 'children', 'income', 'age_in_days', 'employment_in_days',
#        'mobile', 'work_phone', 'phone', 'email', 'family_members',
#        'months_balance'],
#       dtype='object')

# %%
df['children'].value_counts()
# Out:
# children
# 0     540639
# 1     155638
# 2      70399
# 3       9328
# 4       1224
# 5        324
# 14       111
# 7         46
# 19         6
# Name: count, dtype: int64

# %%
df.groupby('children')[['loan_status']].value_counts().unstack()
# Out:
# loan_status  1st_month_due  2nd_month_due  3rd_month_due  4th_month_due  \
# children
# 0                 201794.0         5908.0          559.0          213.0
# 1                  58550.0         1801.0          156.0           51.0
# 2                  26171.0          888.0           64.0           17.0
# 3                   3468.0          119.0           21.0            4.0
# 4                    490.0           16.0            1.0            1.0
# 5                     79.0            NaN            NaN            NaN
# 7                     14.0           10.0            NaN            NaN
# 14                    82.0            5.0            NaN            NaN
# 19                     6.0            NaN            NaN            NaN
#
# loan_status  5th_month_due  bad_debt      good   no_loan
# children
# 0                    146.0     994.0  230268.0  100757.0
# 1                     46.0     434.0   64120.0   30480.0
# 2                     20.0      92.0   30485.0   12662.0
# 3                      1.0       5.0    4143.0    1567.0
# 4                      1.0       2.0     416.0     297.0
# 5                      NaN       NaN      82.0     163.0
# 7                      NaN       NaN      22.0       NaN
# 14                     NaN       NaN       NaN      24.0
# 19                     NaN       NaN       NaN       NaN

# %% [markdown]
# #### Getting insights from employment_in_days

# %%
df['employment_in_days'].plot(kind='hist')
plt.title('Frequency of employment_in_days')
plt.show()

# %%
df[df['employment_in_days'] >0].value_counts().sum()
# Out:
# 127972

# %% [markdown]
# ### Observations:
# * The value in employment in days that are greater than 0 shows the status of the person is unemployed.
# * We have 127972 people who are unemployed.

# %% [markdown]
# #### Checking the relationship between employment_in_days >0 (unemployed) and loan_status

# %%
count = df[df['employment_in_days']>0]
count.groupby('loan_status').size()
# Out:
# loan_status
# 1st_month_due    47620
# 2nd_month_due     1128
# 3rd_month_due      149
# 4th_month_due       73
# 5th_month_due       37
# bad_debt           266
# good             55172
# no_loan          23527
# dtype: int64

# %% [markdown]
# #### Observations:
# * The loan_status of the most of the unemployed persons is good , first month due & no_loan which is a positive trend.
# * Whereas, the loan_status of the bad_debt for unemployed persons is very low.

# %% [markdown]
# ## Data Preprocessing

# %%
df.columns
# Out:
# Index(['ID', 'gender', 'own_car', 'own_property', 'children', 'income',
#        'income_type', 'education', 'family_status', 'housing_type',
#        'age_in_days', 'employment_in_days', 'mobile', 'work_phone', 'phone',
#        'email', 'family_members', 'months_balance', 'status', 'loan_status'],
#       dtype='object')

# %% [markdown]
# #### Plotting scatterplot for numeric column

# %%
col = ['children', 'income', 'age_in_days', 'family_members', 'employment_in_days']

plt.figure(figsize=(15,9))
for i in range(len(col)):
    plt.subplot(3, 2, i+1)
    plt.title(col[i])
    sns.scatterplot(data=df, y=col[i], x='ID')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Plotting boxplot of numeric column

# %%
col = ['children', 'income', 'age_in_days', 'family_members']

plt.figure(figsize=(15,6))
for i in range(len(col)):
    plt.subplot(2,2,i+1)
    plt.title(col[i])
    sns.boxplot(y=col[i], data=df)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observations:
# * As we can see that the outliers are present in three columns:
# income,
# children,
# family_members
# * Both scatter plot and box plot are showing outliers in the above mention columns.

# %% [markdown]
# #### Removing outliers from ['children', 'income', 'family_memebers']

# %%
# filtering the list of specific columns
col = ['children', 'income' , 'family_members']

# for loop to remove outliers
for i in range(len(col)):
    # calculating the first and third quartile
    q1 = df[col[i]].quantile(0.25)
    q3 = df[col[i]].quantile(0.75)
    # calculating the interquartile range
    iqr = q3 - q1
    # calculating the lower and upper bounds
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    # replacing the outliers with the median
    df[col[i]] = np.where((df[col[i]] >= upper_bound) | (df[col[i]] <= lower_bound), df[col[i]].median() , df[col[i]])

# %%
#### again plotting boxplot to confirm outcomes

col= ['children', 'income', 'family_members']

plt.figure(figsize=(15,6))
for i in range(len(col)):
    plt.subplot(2,2,i+1)
    plt.title(col[i])
    sns.boxplot(y=col[i], data=df)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Correlation matrix for numerical features

# %%
corr_matrix =df[['children', 'income', 'age_in_days', 'family_members', 'employment_in_days', 'months_balance']].corr()
plt.figure(figsize=(15,6))
sns.heatmap(corr_matrix, annot=True, cbar=False)
plt.title('Heatmap for Correlation Matrix for numerical features')
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# ### Observation
# * As we can see that children and family_members are highly correlated with each other.
# * But there is no strong correlation between other numerical features.
